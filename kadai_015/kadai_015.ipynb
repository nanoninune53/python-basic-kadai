# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(f"名前：{self.name},年齢：{self.age}")

taro = Human("太郎", 23)
taro.printinfo()
# Out:
# 名前：太郎,年齢：23
