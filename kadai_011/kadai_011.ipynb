# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for i in array:
    print(i)

v = 0
while v < len(array):
    print(array[v])
    v += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
